# %% [markdown]
# # TNT VGG16 512 Model

# %%
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load VGG16 without the top (classification) layers
base_model = VGG16(weights="imagenet", include_top=False, input_shape=(512, 512, 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 512, 512, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 512, 512, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 512, 512, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 256, 256, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 256, 256, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 128, 128, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 64, 64, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Freeze the convolutional base (optional, speeds up training)
base_model.trainable = False

# %%
# Add new custom layers for binary classification
x = Flatten()(base_model.output) # Flattens the output of the base model
x = Dense(512, activation="relu")(x) # Fully connected layer with 512 neurons
x = Dropout(0.5)(x)  # Prevent overfitting, randomly drops 50% of neurons
x = Dense(1, activation="sigmoid")(x)  # Single neuron the ouputs probability score

# %%
# Create the new model
model = Model(inputs=base_model.input, outputs=x)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 512, 512, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 512, 512, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 512, 512, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 256, 256, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 256, 256, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 128, 128, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 64, 64, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │    67,109,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,824,577 (312.14 MB)
#  Trainable params: 67,109,889 (256.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# Compile the model for binary classification
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 512, 512, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 512, 512, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 512, 512, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 256, 256, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 256, 256, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 128, 128, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 64, 64, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │    67,109,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,824,577 (312.14 MB)
#  Trainable params: 67,109,889 (256.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# Define directories
train_dir = '/Users/danieldobrenz/Documents/DATA SCIENCE DOCUMENTS/DATA/Magnimind/AI Imaging/MedImgIntro-WORKSHOP-main/Second Projects/TNT Project/TNT Images 512x512'

# %%
# Create data generator with augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize images
    rotation_range=20,  # Augmentations
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Split dataset (80% train, 20% validation)
)

# %%
# Load training data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(512, 512),  # VGG16 input size
    batch_size=32,
    class_mode="binary",  # Binary classification
    subset="training"
)
# Out:
# Found 21 images belonging to 2 classes.

# %%
# Load validation data
val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(512, 512),
    batch_size=32,
    class_mode="binary",
    subset="validation"
)
# Out:
# Found 4 images belonging to 2 classes.

# %%
# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100  # Adjust as needed
)

# Save the trained model
model.save("vgg16_binary_classifier.keras")
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step - accuracy: 0.2857 - loss: 1.2036 - val_accuracy: 0.7500 - val_loss: 0.5217
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.6667 - loss: 0.5955 - val_accuracy: 0.7500 - val_loss: 0.6671
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 18s 18s/step - accuracy: 0.7143 - loss: 0.6586 - val_accuracy: 0.7500 - val_loss: 0.7136
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.8214 - val_accuracy: 0.7500 - val_loss: 0.6959
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.7434 - val_accuracy: 0.7500 - val_loss: 0.6067
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.7143 - loss: 0.8644 - val_accuracy: 0.7500 - val_loss: 0.5982
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.6667 - loss: 0.6648 - val_accuracy: 0.7500 - val_loss: 0.4949
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.6667 - loss: 0.6380 - val_accuracy: 0.7500 - val_loss: 0.4266
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.6667 - loss: 0.6450 - val_accuracy: 1.0000 - val_loss: 0.6182
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.6667 - loss: 0.6479 - val_accuracy: 0.5000 - val_loss: 0.7245
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.4286 - loss: 0.7539 - val_accuracy: 0.7500 - val_loss: 0.6722
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.6667 - loss: 0.6825 - val_accuracy: 0.7500 - val_loss: 0.6262
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.5714 - loss: 0.6426 - val_accuracy: 0.7500 - val_loss: 0.6113
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.6190 - loss: 0.6663 - val_accuracy: 0.7500 - val_loss: 0.5460
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.7619 - loss: 0.4523 - val_accuracy: 0.7500 - val_loss: 0.5072
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7619 - loss: 0.5315 - val_accuracy: 0.7500 - val_loss: 0.5306
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.7135 - val_accuracy: 0.7500 - val_loss: 0.5773
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.6667 - loss: 0.6818 - val_accuracy: 0.7500 - val_loss: 0.5509
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.6073 - val_accuracy: 0.7500 - val_loss: 0.5332
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.6147 - val_accuracy: 0.7500 - val_loss: 0.5185
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.7619 - loss: 0.4477 - val_accuracy: 0.7500 - val_loss: 0.5443
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.5776 - val_accuracy: 0.7500 - val_loss: 0.4405
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.6019 - val_accuracy: 0.7500 - val_loss: 0.4878
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8571 - loss: 0.4652 - val_accuracy: 0.7500 - val_loss: 0.5373
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.6190 - loss: 0.5801 - val_accuracy: 0.7500 - val_loss: 0.4621
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.5714 - loss: 0.6545 - val_accuracy: 0.7500 - val_loss: 0.4950
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.7619 - loss: 0.5856 - val_accuracy: 0.7500 - val_loss: 0.4562
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.7619 - loss: 0.5163 - val_accuracy: 0.7500 - val_loss: 0.4792
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8571 - loss: 0.4824 - val_accuracy: 0.7500 - val_loss: 0.4695
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8095 - loss: 0.5037 - val_accuracy: 0.7500 - val_loss: 0.4916
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.6667 - loss: 0.6766 - val_accuracy: 0.7500 - val_loss: 0.4517
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.6667 - loss: 0.5869 - val_accuracy: 0.7500 - val_loss: 0.4897
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7619 - loss: 0.5855 - val_accuracy: 0.7500 - val_loss: 0.4221
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7619 - loss: 0.5478 - val_accuracy: 0.7500 - val_loss: 0.4607
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7619 - loss: 0.5904 - val_accuracy: 0.7500 - val_loss: 0.4510
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8095 - loss: 0.5192 - val_accuracy: 0.7500 - val_loss: 0.4843
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.7143 - loss: 0.5696 - val_accuracy: 0.7500 - val_loss: 0.4813
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step - accuracy: 0.6667 - loss: 0.6139 - val_accuracy: 0.7500 - val_loss: 0.4334
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step - accuracy: 0.8571 - loss: 0.4465 - val_accuracy: 0.7500 - val_loss: 0.4262
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 25s 25s/step - accuracy: 0.6667 - loss: 0.5650 - val_accuracy: 0.7500 - val_loss: 0.4326
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 27s 27s/step - accuracy: 0.8095 - loss: 0.4883 - val_accuracy: 0.7500 - val_loss: 0.5095
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step - accuracy: 0.7143 - loss: 0.4831 - val_accuracy: 0.7500 - val_loss: 0.4809
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step - accuracy: 0.8571 - loss: 0.4223 - val_accuracy: 0.7500 - val_loss: 0.3811
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step - accuracy: 0.8095 - loss: 0.4790 - val_accuracy: 0.7500 - val_loss: 0.4754
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step - accuracy: 0.7143 - loss: 0.6502 - val_accuracy: 0.7500 - val_loss: 0.4787
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step - accuracy: 0.7619 - loss: 0.4572 - val_accuracy: 0.7500 - val_loss: 0.3764
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 29s 29s/step - accuracy: 0.8095 - loss: 0.3945 - val_accuracy: 0.7500 - val_loss: 0.4704
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 28s 28s/step - accuracy: 0.7143 - loss: 0.4772 - val_accuracy: 0.7500 - val_loss: 0.5171
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 25s 25s/step - accuracy: 0.7143 - loss: 0.4960 - val_accuracy: 0.7500 - val_loss: 0.5348
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 24s 24s/step - accuracy: 0.8095 - loss: 0.4720 - val_accuracy: 0.7500 - val_loss: 0.5899
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 26s 26s/step - accuracy: 0.7619 - loss: 0.4607 - val_accuracy: 0.7500 - val_loss: 0.4722
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 25s 25s/step - accuracy: 0.8571 - loss: 0.4211 - val_accuracy: 0.7500 - val_loss: 0.4721
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 25s 25s/step - accuracy: 0.8095 - loss: 0.4815 - val_accuracy: 1.0000 - val_loss: 0.3045
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 26s 26s/step - accuracy: 0.9048 - loss: 0.4337 - val_accuracy: 0.7500 - val_loss: 0.4059
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 25s 25s/step - accuracy: 0.6667 - loss: 0.6271 - val_accuracy: 0.7500 - val_loss: 0.4244
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 26s 26s/step - accuracy: 0.6667 - loss: 0.5074 - val_accuracy: 0.7500 - val_loss: 0.4081
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 26s 26s/step - accuracy: 0.7619 - loss: 0.4350 - val_accuracy: 0.7500 - val_loss: 0.4566
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 26s 26s/step - accuracy: 0.7619 - loss: 0.5091 - val_accuracy: 0.7500 - val_loss: 0.4393
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 26s 26s/step - accuracy: 0.8571 - loss: 0.3732 - val_accuracy: 0.7500 - val_loss: 0.4213
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 26s 26s/step - accuracy: 0.7619 - loss: 0.4325 - val_accuracy: 0.7500 - val_loss: 0.4555
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 22s 22s/step - accuracy: 0.6667 - loss: 0.5599 - val_accuracy: 0.7500 - val_loss: 0.4540
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 25s 25s/step - accuracy: 0.8571 - loss: 0.6156 - val_accuracy: 0.7500 - val_loss: 0.3495
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 20s 20s/step - accuracy: 0.7619 - loss: 0.4841 - val_accuracy: 0.7500 - val_loss: 0.3909
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.5172 - val_accuracy: 0.7500 - val_loss: 0.4595
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7619 - loss: 0.4570 - val_accuracy: 0.7500 - val_loss: 0.4477
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.7143 - loss: 0.4119 - val_accuracy: 0.7500 - val_loss: 0.3755
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.4969 - val_accuracy: 0.7500 - val_loss: 0.5090
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8571 - loss: 0.4251 - val_accuracy: 0.7500 - val_loss: 0.4269
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.4737 - val_accuracy: 0.7500 - val_loss: 0.3959
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.9048 - loss: 0.3053 - val_accuracy: 0.7500 - val_loss: 0.4573
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.9524 - loss: 0.3399 - val_accuracy: 0.7500 - val_loss: 0.4261
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - accuracy: 0.7143 - loss: 0.5091 - val_accuracy: 0.7500 - val_loss: 0.3759
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.9048 - loss: 0.4494 - val_accuracy: 0.7500 - val_loss: 0.3867
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8095 - loss: 0.3654 - val_accuracy: 0.7500 - val_loss: 0.4459
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7619 - loss: 0.4433 - val_accuracy: 0.7500 - val_loss: 0.4673
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8095 - loss: 0.3630 - val_accuracy: 0.7500 - val_loss: 0.4622
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8095 - loss: 0.4975 - val_accuracy: 0.7500 - val_loss: 0.4604
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8571 - loss: 0.4811 - val_accuracy: 1.0000 - val_loss: 0.2984
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.6667 - loss: 0.5039 - val_accuracy: 0.7500 - val_loss: 0.3630
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8571 - loss: 0.3946 - val_accuracy: 0.7500 - val_loss: 0.3467
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8095 - loss: 0.4669 - val_accuracy: 0.7500 - val_loss: 0.3864
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8095 - loss: 0.4260 - val_accuracy: 0.7500 - val_loss: 0.4263
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.9048 - loss: 0.3830 - val_accuracy: 0.7500 - val_loss: 0.3792
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.9048 - loss: 0.3281 - val_accuracy: 0.7500 - val_loss: 0.4345
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8571 - loss: 0.4272 - val_accuracy: 0.7500 - val_loss: 0.3555
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8095 - loss: 0.4676 - val_accuracy: 0.7500 - val_loss: 0.5146
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.7143 - loss: 0.4081 - val_accuracy: 0.7500 - val_loss: 0.4267
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8571 - loss: 0.3598 - val_accuracy: 0.7500 - val_loss: 0.4922
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8571 - loss: 0.4688 - val_accuracy: 0.7500 - val_loss: 0.3962
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8571 - loss: 0.3947 - val_accuracy: 0.7500 - val_loss: 0.4454
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8571 - loss: 0.3759 - val_accuracy: 0.7500 - val_loss: 0.4126
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8095 - loss: 0.3844 - val_accuracy: 0.7500 - val_loss: 0.3979
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.9048 - loss: 0.4306 - val_accuracy: 0.7500 - val_loss: 0.4907
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.9048 - loss: 0.3007 - val_accuracy: 0.7500 - val_loss: 0.4991
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8095 - loss: 0.3971 - val_accuracy: 0.7500 - val_loss: 0.3953
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.8095 - loss: 0.4853 - val_accuracy: 0.7500 - val_loss: 0.4263
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.6667 - loss: 0.5102 - val_accuracy: 0.7500 - val_loss: 0.5871
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.8095 - loss: 0.3987 - val_accuracy: 0.7500 - val_loss: 0.3672
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 22s 22s/step - accuracy: 0.8095 - loss: 0.4061 - val_accuracy: 0.7500 - val_loss: 0.4619
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - accuracy: 0.9048 - loss: 0.2857 - val_accuracy: 0.7500 - val_loss: 0.5473

# %%
# Plot training & validation loss and accuracy
def plot_training_history(history):
    plt.figure(figsize=(12, 5))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Loss Over Epochs")
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history["accuracy"], label="Training Accuracy")
    plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.title("Accuracy Over Epochs")
    plt.legend()

    # Show plot
    plt.show()

# Call function to plot
plot_training_history(history)

# %% [markdown]
# Summary of the Two Plots
# 1. Loss Over Epochs (Left Plot)
# - The training loss (blue line) and validation loss (orange line) both show a general decreasing trend over 100 epochs, which indicates that the model is learning.
# - The training loss is highly fluctuating, suggesting possible instability in training (e.g., high learning rate or batch variability).
# - The validation loss also decreases but remains noisy, implying potential overfitting or irregular generalization.
# 2. Accuracy Over Epochs (Right Plot)
# - The training accuracy (blue line) shows an increasing trend with fluctuations, meaning the model is gradually improving its performance.
# - The validation accuracy (orange line) is highly unstable, showing sharp jumps and dips, which could indicate overfitting, data inconsistency, or an unstable training process.
# - In many epochs, validation accuracy is higher than training accuracy, which might be due to randomness in validation batch sampling or batch normalization effects.
#
# Key Observations & Recommendations
# - High Variability: Both loss and accuracy fluctuate significantly. Consider:
#   - Using a lower learning rate.
#   - Increasing the batch size for smoother training.
#   - Applying regularization (dropout, L2 weight decay).
# - Possible Overfitting: Validation metrics are more unstable than training ones.
#   - Consider using early stopping to prevent training too long.
#   - Introduce data augmentation to improve generalization.
